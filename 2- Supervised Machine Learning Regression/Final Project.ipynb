# %% [markdown]
# # Car Price Prediction and Interpretation
# ## - The two main goals of this project are:
# * Predicting the price of a car according to a certain set of features
# * Comparing LinearRegression, RidgeRegression and LassoRegression performances
#
# ## - Data Description
# The dataset consists of many different car types and models with their prices included, it also contains many features of each car such as the dimensions of the car, engine size, hourse power and many other features that we're going to use in order to predict the car price.
# ## - Data exploration
# I started by loading the data into jupyter notebook using pandas, then eliminated some of the columns that are irrelecant to the target feature. Cosecutively, I checked the number of featues that are object (containing strings) and one hot encoded them to enclode them in the regression models, some of them were nominal and some of them were ordinal.
# ###  Loading the Data

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("C:/Users/HP/Desktop/IBM machine learning/2- Supervised Machine Learning Regression/Final Project/CarPrice_Assignment.csv")

data = data.drop("car_ID", axis=1) #  removing the care ID column since it's no different from the index
data = data.drop("CarName", axis=1) # removing the CarName column since it's irrelevant to the car price
data.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8      64.1  ...         130        mpfi
# 1          front       88.6      168.8      64.1  ...         130        mpfi
# 2          front       94.5      171.2      65.5  ...         152        mpfi
# 3          front       99.8      176.6      66.2  ...         109        mpfi
# 4          front       99.4      176.6      66.4  ...         136        mpfi
#
#   boreratio stroke  compressionratio horsepower  peakrpm  citympg  highwaympg  \
# 0      3.47   2.68               9.0        111     5000       21          27
# 1      3.47   2.68               9.0        111     5000       21          27
# 2      2.68   3.47               9.0        154     5000       19          26
# 3      3.19   3.40              10.0        102     5500       24          30
# 4      3.19   3.40               8.0        115     5500       18          22
#
#      price
# 0  13495.0
# 1  16500.0
# 2  16500.0
# 3  13950.0
# 4  17450.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Checking columns types

# %%
# Select the object (string) columns
data.dtypes.value_counts()
# Out:
# object     9
# float64    8
# int64      7
# dtype: int64

# %% [markdown]
# ### one hot encoding the categorical variables

# %%
# Select the object (string) columns
mask = data.dtypes == np.object
categorical_cols = data.columns[mask]
# Out:
# <ipython-input-90-b129c89aea04>:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = data.dtypes == np.object

# %%
# Determine how many extra columns would be created
num_ohc_cols = (data[categorical_cols]
                .apply(lambda x: x.nunique())
                .sort_values(ascending=False))


# No need to encode if there is only one value
small_num_ohc_cols = num_ohc_cols.loc[num_ohc_cols>1]

# Number of one-hot columns is one less than the number of categories
small_num_ohc_cols -= 1

# This is 175 columns, assuming the original ones are dropped. 
# This is quite a few extra columns!
small_num_ohc_cols.sum()
# Out:
# 29

# %%
from sklearn.preprocessing import OneHotEncoder

# Copy of the data
data_ohc = data.copy()

# The encoder
ohc = OneHotEncoder()

for col in num_ohc_cols.index:
    
    # One hot encode the data--this returns a sparse array
    new_dat = ohc.fit_transform(data_ohc[[col]])
    
    # Remove the original column from the dataframe
    data_ohc = data_ohc.drop(col, axis=1)

    # get names of all the unique values in the colunm so we can identify later
    cats = ohc.categories_

    # Create columns names for each OHE by value
    new_cols = ['_'.join([col, cat]) for cat in cats[0]]

    # Create the new dataframe
    new_df = pd.DataFrame(new_dat.toarray(),
                          columns=new_cols)

    # Append the new data to the dataframe
    data_ohc = pd.concat([data_ohc, new_df], axis=1)

# %%
# Column difference is as calculated above
data_ohc.shape[1] - data.shape[1]
# Out:
# 29

# %%
print(data.shape[1])

# Remove the string columns from the dataframe
data = data.drop(num_ohc_cols.index, axis=1)

print(data.shape[1])
# Out:
# 24
# 15

# %% [markdown]
# ### Training and test splits

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
# standard scaling all x before splitting
s = StandardScaler()

y_col = 'price'
# Split the data that is one-hot encoded
feature_cols = [x for x in data_ohc.columns if x != y_col]
X_data_ohc = data_ohc[feature_cols]
X_data_ohc = s.fit_transform(X_data_ohc)
y_data_ohc = data_ohc[y_col]

X_train_ohc, X_test_ohc, y_train_ohc, y_test_ohc = train_test_split(X_data_ohc, y_data_ohc, 
                                                    test_size=0.3, random_state=42)

# %% [markdown]
# ### Using Grid Search CV to find the best parameters.

# %% [markdown]
# #### - Needed Libraries

# %%
from sklearn.model_selection import KFold, cross_val_predict
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #### 1- linear regression

# %%
# without PolynomialFeatures transformation
lr_error_df = list()
lr = LinearRegression()
lr = lr.fit(X_train_ohc,y_train_ohc )
y_pred_LR = lr.predict(X_test_ohc)

lr_error_df.append(pd.Series({'Accuracy': r2_score(y_test_ohc, y_pred_LR)},
                           name='no PolynomialFeatures'))

# using grid search cv to apply polynomial features tranformtion
estimator = Pipeline([("polynomial_features", PolynomialFeatures()),
        ("linear_regression", LinearRegression())])

params = {
    'polynomial_features__degree': [1, 2, 3]
}
kf = KFold(shuffle=True, random_state=72019, n_splits=3)

grid = GridSearchCV(estimator, params, cv=kf)
grid.fit(X_train_ohc,y_train_ohc)
grid_y_pred_LRP = grid.predict(X_test_ohc)
lr_error_df.append(pd.Series({'Accuracy': r2_score(y_test_ohc,grid_y_pred_LRP)},
                           name='PolynomialFeatures'))
lr_error_df = pd.concat(lr_error_df, axis=1)
lr_error_df
# Out:
#           no PolynomialFeatures  PolynomialFeatures
# Accuracy               0.883029            0.883029

# %% [markdown]
# AS we can see above, polynomial transformation did not change the accuracy of the Linear regression model.
# #### 2- Ridge Regression (regularization regression)

# %%
# without polynomial transformation
RG_error_df = list()
estimator_R = Pipeline([("ridge_regression", Ridge())])

params_R = {
    'ridge_regression__alpha': np.geomspace(0.1, 10, 30)
}

grid_R = GridSearchCV(estimator_R, params_R, cv=kf)
grid_R.fit(X_train_ohc,y_train_ohc)
grid_y_pred_R = grid_R.predict(X_test_ohc)
RG_error_df.append(pd.Series({'Accuracy': r2_score(y_test_ohc,grid_y_pred_R)},
                           name='No PolynomialFeatures'))

# with polynomial transformation
estimator_RP = Pipeline([("polynomial_features", PolynomialFeatures()),
        ("ridge_regression", Ridge())])

params_RP = {
    'polynomial_features__degree': [1, 2, 3],
    'ridge_regression__alpha': np.geomspace(0.1, 10, 30)
}
grid_RP = GridSearchCV(estimator_RP, params_RP, cv=kf)
grid_RP.fit(X_train_ohc,y_train_ohc)
grid_y_pred_RP = grid_RP.predict(X_test_ohc)
RG_error_df.append(pd.Series({'Accuracy': r2_score(y_test_ohc,grid_y_pred_RP)},
                           name='PolynomialFeatures'))


RG_error_df = pd.concat(RG_error_df, axis=1)
RG_error_df
# Out:
#           No PolynomialFeatures  PolynomialFeatures
# Accuracy               0.863438            0.863438

# %%
print(r2_score(y_test_ohc,grid_y_pred_RP))
print(r2_score(y_test_ohc,grid_y_pred_R))
# Out:
# 0.8634379859751133
# 0.8634379859751131

# %% [markdown]
# As we can see above, the difference between using polynomial transformation and not using it is in the 16th decimal, which mean it's insignificant.
#
# #### 2- Lasso Regression (regularization regression)

# %%
# without polynomial transformation
L_error_df = list()
estimator_L = Pipeline([("Lasso_regression", Lasso())])

params_L = {
    'Lasso_regression__alpha': np.geomspace(4, 20, 30)
}

grid_L = GridSearchCV(estimator_L, params_L, cv=kf)
grid_L.fit(X_train_ohc,y_train_ohc)
grid_y_pred_L = grid_L.predict(X_test_ohc)
L_error_df.append(pd.Series({'Accuracy': r2_score(y_test_ohc,grid_y_pred_L)},
                           name='No PolynomialFeatures'))

# with polynomial transformation
estimator_LP = Pipeline([("polynomial_features", PolynomialFeatures()),
        ("Lasso_regression", Lasso())])

params_LP = {
    'polynomial_features__degree': [1, 2, 3],
    'Lasso_regression__alpha': np.geomspace(4, 20, 30)
}
grid_LP = GridSearchCV(estimator_LP, params_LP, cv=kf)
grid_LP.fit(X_train_ohc,y_train_ohc)
grid_y_pred_LP = grid_LP.predict(X_test_ohc)
L_error_df.append(pd.Series({'Accuracy': r2_score(y_test_ohc,grid_y_pred_LP)},
                           name='PolynomialFeatures'))


L_error_df = pd.concat(L_error_df, axis=1)
L_error_df
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1690501.7234973907, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1732890.4434927702, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1774963.9745263457, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1698716.521698296, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1781831.9829675257, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1853844.5948140621, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1907721.7561048567, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1936844.2426624, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1989581.3131843805, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2053751.1157484949, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2116799.2359837294, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2176155.8094652593, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1690501.7234973907, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5090759.709455522, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6682031.211113404, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3653457.407540747, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9369608.051958445, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9262054.856394196, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8933917.113097042, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1732890.4434927702, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4249251.143394981, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6599125.912947713, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4454058.8119990025, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12314162.274977788, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9147466.395390522, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9022487.9722956, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1774963.9745263457, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4031142.279355252, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6335211.432230004, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3546872.3677206263, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11021888.93645282, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8564261.131905269, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9385063.5463715, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1698716.521698296, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4336978.264329668, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5961331.215524903, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3080584.837245725, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11881482.870544199, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8884645.122052787, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9330300.353491515, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1781831.9829675257, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4542377.67922397, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5977662.66863673, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2900645.8741527237, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10901624.430239629, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8892854.967812091, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10037850.392642915, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1853844.5948140621, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5094980.338528905, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6427747.841267558, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2629659.8474016814, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10112311.415220715, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9016935.68072087, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10482985.9926796, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1907721.7561048567, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5388709.439530846, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3982872.3478620667, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3334684.0958490632, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11525066.620272743, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9312824.890919317, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10591501.947091587, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1936844.2426624, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5086758.839189064, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3206371.9818194397, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3670309.765667975, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10377442.801671073, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9500696.654752173, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10849086.857610561, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1989581.3131843805, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3759091.33637025, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2801645.18754616, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4329911.287776095, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10346327.118204508, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9727250.61103076, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11356386.16278749, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2053751.1157484949, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3450819.402119525, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2663220.845135335, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4515469.021758038, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10766340.015024787, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9987082.924521709, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11518581.889470147, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2116799.2359837294, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3470144.917470902, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4214084.648107279, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4525738.6591824405, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10468094.003828885, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10190751.94497962, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11619199.89550803, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2176155.8094652593, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4404771.511437735, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4430209.253971234, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3424694.067968929, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10647418.762950419, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10447516.642238287, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12086994.749249142, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3036086.5360210612, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2633832.5212410353, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3580186.8253993746, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10768264.412427835, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10698057.100323692, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12802251.737263985, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3981784.800970532, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2767403.326682437, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3464766.651617948, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11053381.510043463, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10750688.029557696, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11532914.271466872, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3644309.9961936176, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3013512.507221956, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3357285.802539792, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11029166.413140386, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10940329.862258535, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12498876.65666693, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2984932.0961347707, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2685445.5622919817, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3649151.040207004, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11842500.527711531, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11350581.328469008, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12359043.132792655, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7382519.428709703, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1935564.2116141021, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4289367.566922937, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11686763.857634826, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11320929.279484581, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13411176.557621805, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8562643.879162505, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 851937.8084303401, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4354113.240817802, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11581031.932062108, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11319010.104183039, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14295018.47993351, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8805820.40931438, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 910970.1468266472, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4275153.720384132, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11935725.421743048, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11708352.729735225, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14727100.785940401, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7947799.877946734, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1079311.2139999345, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4457828.08286025, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18841529.047093168, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11663719.946517847, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14558905.998670544, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8150505.9537165165, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1254251.6767357104, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4691565.807919219, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18271018.337583546, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11471582.682301529, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7009346.733316831, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8387833.897066154, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 778684.4140880108, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4807009.8936925195, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19029085.847128063, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11499273.305078544, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8412442.8946923, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8705090.619608022, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 956361.0212072991, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4355877.846948121, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19754567.501237188, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11803837.920519888, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15374405.923326612, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8975906.75291105, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1028010.1397881471, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4128341.316198323, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18197142.862599485, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11718492.377819588, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18130469.114476513, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9363066.352652758, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1172932.9580141716, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4064574.115268104, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16745595.370694747, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12236248.30030557, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19006090.22456791, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1734545.2584934868, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 737283.0326592289, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4270930.759839736, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16008212.742188733, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20967778.52235114, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19333777.513581313, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 984580.4456235021, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4410737.302444501, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12050067.369032297, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12233960.147164196, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19392372.286552336, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 794401.6099910028, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4491192.104707707, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11077557.291602593, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11732684.420541162, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21181584.096789077, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 798391.7080718465, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2217515.3493131474, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11085562.615957953, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13574403.084520958, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22719506.94174254, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 713299.2075912431, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 527716.5065605417, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 834447.4616739526, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10184160.134374518, tolerance: 563951.3343726316
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12125741.391977135, tolerance: 523466.7270931579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22044707.049866036, tolerance: 649766.7343333333
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1933490.8223858625, tolerance: 871579.5255248253
#   model = cd_fast.enet_coordinate_descent(
#           No PolynomialFeatures  PolynomialFeatures
# Accuracy               0.881807            0.926257

# %% [markdown]
# ### comparing the results of the three different models

# %%
error_df = list()
error_df.append(pd.Series({'LinearRgression': r2_score(y_test_ohc,y_pred_LR),
                          'RidgeRegression': r2_score(y_test_ohc,grid_y_pred_R),
                          'LassoRegression': r2_score(y_test_ohc,grid_y_pred_L)},
                           name='No PolynomialFeatures'))
error_df.append(pd.Series({'LinearRgression': r2_score(y_test_ohc,grid_y_pred_LRP),
                          'RidgeRegression': r2_score(y_test_ohc,grid_y_pred_RP),
                          'LassoRegression': r2_score(y_test_ohc,grid_y_pred_LP)},
                           name='No PolynomialFeatures'))

error_df = pd.concat(error_df, axis=1)
error_df
# Out:
#                  No PolynomialFeatures  No PolynomialFeatures
# LinearRgression               0.883029               0.883029
# RidgeRegression               0.862456               0.862456
# LassoRegression               0.881807               0.926257

# %% [markdown]
# ## Recommendation
# As my goal was to score the highest accuracy, I was expecting that Ridge regression would scare the highest accuracy, because it has high penalty in regularization, which means it has less error on the expense of less interpretability. Surprisingly, Lasso Regression model scored a higher accuracy altho it's better for model and features interpretability since it zeros out more features than Ridge regression model. Moreover, this is most likely due to better tuning for Lasso model than Ridge model.

# %% [markdown]
# ## Key Findings
# in LinearRegression and Ridgeregression, applying polynomial transformation had a small impact on the accuracy of the model. on the other hand, applying polynomial transformation on Lasso regression model increased the accuracy significantly. Surprisingly, Ridge Regression scored the lowest accuracy although it was expected to score the highest one.

# %% [markdown]
# ## Suggestions
# I believe it's really important to do further analyses into why Ridge regression model scored the lowest accuracy, we should try to tune the model in different ways apply different scaling and check the results again to see if there is an changes.
